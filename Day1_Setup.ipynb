# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanb1996/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid categorizes the diverse skill sets needed to build and deploy AI, from foundational to advanced:
#
# *   **Data & Core ML Engineering:** The base, focusing on data collection, cleaning, feature engineering, and implementing fundamental machine learning models.
# *   **MLOps & Deployment:** Operationalizing AI by deploying models into production environments, monitoring performance, and managing the AI lifecycle.
# *   **AI Product Management:** Defining AI applications, understanding user needs, and ensuring AI solutions deliver strategic business value and impact.
# *   **AI Research & Innovation:** The apex, dedicated to advancing the state-of-the-art by developing new algorithms, theoretical foundations, and pushing AI capabilities.

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the hierarchical skills needed for successful AI implementation, moving from foundational technical skills to strategic impact:
#
# *   **Technical Foundation:** The base, encompassing data engineering, infrastructure, and core machine learning model development.
# *   **Problem Formulation & Domain Expertise:** The ability to define real-world problems and translate them into AI-addressable challenges with relevant domain knowledge.
# *   **Ethical & Responsible AI:** Focuses on ensuring fairness, transparency, privacy, and accountability in AI systems throughout their lifecycle.
# *   **Real-world Impact:** The apex, concerned with delivering tangible business value, excellent user experience, and strategic integration of AI solutions.
